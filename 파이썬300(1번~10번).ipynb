# %% [markdown]
# <a href="https://colab.research.google.com/github/yangkong2/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC300(1%EB%B2%88~10%EB%B2%88).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print("Mary's cometics") #파이썬이 구별하기 힘들기 때문에 다르게 표현
# Out:
# Mary's cometics

# %%
print('신씨가 소리를 질렀다. "도둑이야."')
# Out:
# 신씨가 소리를 질렀다. "도둑이야."

# %%
print("C:\\Windows") #역슬래시를 표함하기 위해선 하나 더 써야 됨
# Out:
# C:\Windows

# %%
print('안녕하세요. \n만나서\t\t반갑습니다')
# Out:
# 안녕하세요.
# 만나서		반갑습니다

# %%
print("오늘은", "일요일") #공백
# Out:
# 오늘은 일요일

# %%
print("naver","kakao","sk","samsung", sep=";") #sep 출력 사이사이 결정
# Out:
# naver;kakao;sk;samsung

# %%
print("naver","kakao","sk","samsung", sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end="");print("second") #한 줄에 한 명령어지만 두 개 이상 시 사이에 세미콜론(;) /  end = " "는 기본값인 \n 대신 ""안에 걸로 결정
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667
